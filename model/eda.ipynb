# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("output.csv")

# %%
import seaborn as sns

sns.scatterplot(x="eps", y="recovery", data=df)
# Out:
# <Axes: xlabel='eps', ylabel='recovery'>

# %%
sns.heatmap(df.corr(), annot=False)
# Out:
# <Axes: >

# %%
sns.pairplot(df[["P_ads", "t_ads", "purity", "recovery"]])

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(df, df["purity"])

importances = model.feature_importances_

# %%
print(importances)
# Out:
# [9.39347290e-05 4.52103465e-05 7.65979837e-05 2.54282076e-04
#  1.15456183e-04 1.30425974e-04 1.17040073e-04 3.23906607e-04
#  4.49791370e-04 4.92386224e-04 4.08362632e-04 4.36625584e-04
#  0.00000000e+00 0.00000000e+00 5.35261832e-01 5.16731070e-05
#  2.01637412e-03 6.05518920e-05 8.09888631e-05 8.59755756e-05
#  3.83441064e-04 8.42912460e-05 4.57924761e-01 1.11469707e-04
#  3.81027776e-05 9.56518862e-04]
