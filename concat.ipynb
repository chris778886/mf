# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('seed10.csv')
df2 = pd.read_csv('seed20.csv')

# %%
df = pd.concat([df1,df2],axis = 0)

# %%
df
# Out:
#     sample_id        tADS        PL        v0    t_press  t_depress  \
# 0           1  121.231639  0.242283  0.011761  64.864674  38.008555
# 1           2  163.806902  0.338393  0.028594  59.693324  65.954041
# 2           3   82.472037  0.230902  0.022071  50.168231  40.971812
# 3           4   96.366813  0.162668  0.021114  53.254276  26.810740
# 4           5  113.613987  0.180127  0.031534  20.341739  60.884987
# ..        ...         ...       ...       ...        ...        ...
# 95         96  145.777050  0.243913  0.029136  54.232775  61.649115
# 96         97  140.514975  0.255564  0.025907  55.085908  62.811383
# 97         98  167.935880  0.347694  0.028414  66.353606  46.403558
# 98         99   74.915355  0.251989  0.026744  34.779592  52.020797
# 99        100  129.675020  0.122520  0.010456  48.138345  48.802843
#
#      h2o_ppmv  sox_ppmv  nox_ppmv  dust_mg_Nm3  ...  n_N2_dynamic_product  \
# 0   27.906160  0.988694  7.974843     0.079348  ...              0.149594
# ...

# %%
df.to_csv('data.csv')
